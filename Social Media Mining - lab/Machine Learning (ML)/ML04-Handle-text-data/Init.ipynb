# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# python -m spacy download en_core_web_sm
# python -m spacy download it_core_news_sm
# Out:
# Collecting spacy-langdetect
#   Downloading spacy_langdetect-0.1.2-py3-none-any.whl (5.0 kB)
# Collecting contextualSpellCheck
#   Downloading contextualSpellCheck-0.4.4-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.1/128.1 kB 13.1 MB/s eta 0:00:00
# Collecting langdetect==1.0.7
#   Downloading langdetect-1.0.7.zip (998 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 998.1/998.1 kB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pytest
#   Downloading pytest-8.2.0-py3-none-any.whl (339 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.2/339.2 kB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from langdetect==1.0.7->spacy-langdetect->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: torch>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from contextualSpellCheck->-r ./requirements.txt (line 2)) (1.12.1)
# Collecting transformers>=4.0.0
#   Downloading transformers-4.40.2-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy>=3.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from contextualSpellCheck->-r ./requirements.txt (line 2)) (3.4.2)
# Collecting editdistance==0.6.2
#   Downloading editdistance-0.6.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 42.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (58.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (8.1.5)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (1.10.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2.4.5)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: numpy>=1.15.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2.28.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.9/py/lib/python3.9/site-packages (from torch>=1.4->contextualSpellCheck->-r ./requirements.txt (line 2)) (4.4.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 41.4 MB/s eta 0:00:00
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 91.2 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.8 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.19.3
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers>=4.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2022.9.13)
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers>=4.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.8.0)
# Collecting tomli>=1
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting pluggy<2.0,>=1.5
#   Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2024.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=20.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pathy>=0.3.5->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (5.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2022.9.24)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->spacy>=3.0.0->contextualSpellCheck->-r ./requirements.txt (line 2)) (2.0.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.7-py3-none-any.whl size=993430 sha256=dd6475c34e0938f58ec1578d9e43982c64afcb92212aa1cc9ce07d44f56da89c
#   Stored in directory: /root/.cache/pip/wheels/4a/03/92/e3a289314c0c6a8e41c67b88a95798b1cc238fba986d2cfe51
# Successfully built langdetect
# Installing collected packages: tomli, safetensors, pyyaml, pluggy, langdetect, iniconfig, exceptiongroup, editdistance, pytest, huggingface-hub, tokenizers, spacy-langdetect, transformers, contextualSpellCheck
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0
#     Not uninstalling pluggy at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pluggy'. No files were found to uninstall.
# Successfully installed contextualSpellCheck-0.4.4 editdistance-0.6.2 exceptiongroup-1.2.1 huggingface-hub-0.23.0 iniconfig-2.0.0 langdetect-1.0.7 pluggy-1.5.0 pytest-8.2.0 pyyaml-6.0.1 safetensors-0.4.3 spacy-langdetect-0.1.2 tokenizers-0.19.1 tomli-2.0.1 transformers-4.40.2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# 2024-05-10 04:29:47.961721: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-10 04:29:48.091654: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:48.091689: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-05-10 04:29:48.110876: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-10 04:29:48.853535: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:48.853631: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:48.853648: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-05-10 04:29:50.115268: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:50.115328: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-05-10 04:29:50.115365: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-ee6c7e19-98ae-4e59-9d2e-ec782149d1e0): /proc/driver/nvidia/version does not exist
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 72.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from en-core-web-sm==3.4.1) (3.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (58.1.0)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.23.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.6.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.12)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.0)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.4.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2024-05-10 04:29:56.035916: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-10 04:29:56.229201: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:56.229253: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-05-10 04:29:56.251944: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-10 04:29:56.868754: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:56.868838: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:56.868850: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-05-10 04:29:58.076934: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-05-10 04:29:58.076980: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-05-10 04:29:58.077007: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-ee6c7e19-98ae-4e59-9d2e-ec782149d1e0): /proc/driver/nvidia/version does not exist
# Collecting it-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.4.0/it_core_news_sm-3.4.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 69.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from it-core-news-sm==3.4.0) (3.4.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2.4.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (3.0.10)
# Requirement already satisfied: pathy>=0.3.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (0.6.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (58.1.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (0.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (1.10.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (1.0.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (8.1.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (1.23.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->it-core-news-sm==3.4.0) (2.0.0)
# Installing collected packages: it-core-news-sm
# Successfully installed it-core-news-sm-3.4.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ee6c7e19-98ae-4e59-9d2e-ec782149d1e0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
