# %%
import networkx as nx
import pickle

# Carica il grafo da un file .pkl
def load_graph_from_pickle(filename):
    
    with open(filename, 'rb') as f:
        graph = pickle.load(f)
    return graph

# Trova i nodi con il grado maggiore e minore
def find_nodes_with_extreme_degrees(graph):
    degrees = dict(graph.degree())
    max_degree_nodes = [node for node, degree in degrees.items() if degree == max(degrees.values())]
    min_degree_nodes = [node for node, degree in degrees.items() if degree == min(degrees.values())]
    return max_degree_nodes, min_degree_nodes

# Esempio di utilizzo
if __name__ == "__main__":
    k = 1
    # Carica il grafo da un file .pkl
    graph = load_graph_from_pickle()
    
    # Trova i nodi con il grado maggiore e minore
    max_degree_nodes, min_degree_nodes = find_nodes_with_extreme_degrees(graph)
    
    # Stampa i risultati
    print("Nodi con grado massimo:", max_degree_nodes)
    print("Nodi con grado minimo:", min_degree_nodes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      20 k = 1
#      21 # Carica il grafo da un file .pkl
# ---> 22 graph = load_graph_from_pickle()
#      24 # Trova i nodi con il grado maggiore e minore
#      25 max_degree_nodes, min_degree_nodes = find_nodes_with_extreme_degrees(graph)
#
# TypeError: load_graph_from_pickle() missing 1 required positional argument: 'filename'

# %%
import networkx as nx
import pickle

# Carica un grafo da un file .pkl
def load_graph_from_pickle(filename):
    with open(filename, 'rb') as f:
        graph = pickle.load(f)
    return graph

# Costruisce un dizionario delle occorrenze dei nodi nei diversi grafi
def build_node_count_dict():
    node_count = {}
    for i in range(1, 15):
        filename = f"viral_genres0{i}.pkl"
        graph = load_graph_from_pickle(filename)
        nodes = list(graph.nodes())
        for node in nodes:
            node_count[node] = node_count.get(node, 0) + 1
    return node_count

# Esempio di utilizzo
if __name__ == "__main__":
    # Costruisce il dizionario delle occorrenze dei nodi
    node_count = build_node_count_dict()
    
    # Ordina il dizionario per valore (occorrenze)
    sorted_node_count = dict(sorted(node_count.items(), key=lambda item: item[1], reverse=True))
    
    # Stampa il dizionario ordinato
    print("Dizionario delle occorrenze dei nodi (ordinato per valore):")
    for node, count in sorted_node_count.items():
        print(node, ":", count)
# Out:
# Dizionario delle occorrenze dei nodi (ordinato per valore):
# urbano latino : 14
# urbano chileno : 14
# mambo chileno : 14
# kashmiri pop : 14
# polish hip hop : 14
# panamanian pop : 13
# reggaeton chileno : 13
# trap latino : 12
# reggaeton : 11
# classic italian pop : 10
# trap chileno : 9
# trap argentino : 7
# filmi : 7
# latin hip hop : 7
# polish viral pop : 7
# afrobeats : 6
# hip hop tuga : 6
# modern bollywood : 6
# reggaeton flow : 6
# r&b en espanol : 6
# egyptian trap : 6
# funk rj : 5
# funk 150 bpm : 5
# pov: indie : 5
# modern rock : 5
# irish singer-songwriter : 5
# israeli mediterranean : 5
# pop : 5
# singer-songwriter pop : 5
# trap boricua : 5
# gujarati pop : 5
# colombian pop : 4
# reggaeton colombiano : 4
# malay rap : 4
# pop argentino : 4
# viet chill rap : 4
# rap : 3
# hip hop : 3
# latin christian : 3
# polish trap : 3
# bulgarian pop : 3
# mahraganat : 3
# german hip hop : 3
# german hyperpop : 3
# post-teen pop : 3
# dance pop : 3
# puerto rican pop : 3
# springfield mo indie : 3
# indie pop : 3
# indian lo-fi : 3
# latin pop : 2
# latin viral pop : 2
# nigerian pop : 2
# pop peruano : 2
# psychedelic pop : 2
# cumbia pop : 2
# russian hip hop : 2
# russian trap : 2
# funk mtg : 2
# chalga : 2
# pop reggaeton : 2
# k-pop : 2
# corrido : 2
# sierreno : 2
# musica mexicana : 2
# sad sierreno : 2
# danish pop : 2
# egyptian pop : 2
# trap : 2
# tagalog rap : 2
# pinoy hip hop : 2
# finnish hip hop : 2
# finnish dance pop : 2
# finnish pop : 2
# french hip hop : 2
# rap francais : 2
# pop urbaine : 2
# j-pop : 2
# greek trap : 2
# desi pop : 2
# mizrahi : 2
# israeli pop : 2
# italian hip hop : 2
# trap italiana : 2
# italian pop : 2
# plugg : 2
# atl hip hop : 2
# melodic rap : 2
# rap maroc : 2
# corridos tumbados : 2
# lustrum : 2
# trap brasileiro : 2
# romanian pop : 2
# czsk hip hop : 2
# drill espanol : 2
# urbano espanol : 2
# amapiano : 2
# swedish pop : 2
# swedish pop rap : 2
# swedish idol pop : 2
# classic swedish pop : 2
# korean ost : 2
# j-division : 2
# german drill : 2
# frauenrap : 2
# czsk hyperpop : 2
# chinese viral pop : 2
# rap tunisien : 2
# argentine indie : 2
# rap underground argentino : 2
# forro : 2
# piseiro : 2
# conscious hip hop : 1
# west coast rap : 1
# lithuanian indie : 1
# lithuanian pop : 1
# afropop : 1
# canadian country : 1
# canadian contemporary country : 1
# sertanejo pop : 1
# sertanejo universitario : 1
# funk bh : 1
# sertanejo : 1
# trap soul : 1
# r&b : 1
# southern hip hop : 1
# pop rap : 1
# rap marseille : 1
# r&b francais : 1
# liedermacher : 1
# german pop : 1
# austropop : 1
# german rock : 1
# canadian pop : 1
# canadian contemporary r&b : 1
# swedish hip hop : 1
# swedish trap pop : 1
# czech hip hop : 1
# czech drill : 1
# dansktop : 1
# classic danish pop : 1
# pluggnb : 1
# rage rap : 1
# albanian hip hop : 1
# viral afropop : 1
# detroit trap brasileiro : 1
# rap dominicano : 1
# bulgarian r&b : 1
# norwegian pop rap : 1
# funk mandelao : 1
# musica madeirense : 1
# turkish trap : 1
# turkce drill : 1
# turkish hip hop : 1
# south asian metal : 1
# classic bollywood : 1
# reggaeton mexicano : 1
