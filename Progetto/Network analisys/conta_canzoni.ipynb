# %%
import csv
import glob

def count_titles_in_csv_files():
    # Dizionario per memorizzare il conteggio dei titoli
    title_count = {}

    # Cerca tutti i file CSV nella stessa cartella del sorgente Python che iniziano con "z-global.csv"
    for i in range(1,16):
        #print("ciao")
        with open(f'0{i}-viral.csv', 'r', encoding = 'utf-16') as csvfile:
            reader = csv.reader(csvfile)
            for row in reader:
                # Ottiene il titolo dalla riga
                #print(row[2])
                title = row[2:]
                print(title)
                # Aggiorna il conteggio del titolo nel dizionario
                title_count[title[0]] = title_count.get(title[0], 0) + 1

    return title_count

# Ottieni il conteggio dei titoli nei file CSV
titles_count = count_titles_in_csv_files()

sorted_titles_count = dict(sorted(titles_count.items(), key=lambda item: item[1], reverse=True))

# Stampare il conteggio dei titoli
for title, count in sorted_titles_count.items():
    print(f"{title}: {count}")
# Out:
# ['titolo', 'artista', 'pubblicazione']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tengo Un Plan', 'Key-Key', '2024-01-07']
# ['Like That', 'Future, Metro Boomin, Kendrick Lamar', '2024-03-22']
# ['Belong Together', 'Mark Ambor', '2024-02-16']
# ['End of Beginning', 'Djo', '2022-09-16']
# ['Midnight Fiction', 'ILLIT', '2024-03-25']
# ['¿Cómo Pasó?', 'Ela Taubert', '2024-02-14']
# ['titolo', 'artista', 'pubblicazione']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-03-15']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tengo Un Plan', 'Key-Key', '2024-01-07']
# ['Like That', 'Future, Metro Boomin, Kendrick Lamar', '2024-03-22']
# ['Belong Together', 'Mark Ambor', '2024-02-16']
# ['End of Beginning', 'Djo', '2022-09-16']
# ['titolo', 'artista', 'pubblicazione']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tengo Un Plan', 'Key-Key', '2024-01-07']
# ['Like That', 'Future, Metro Boomin, Kendrick Lamar', '2024-03-22']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Belong Together', 'Mark Ambor', '2024-02-16']
# ['titolo', 'artista', 'pubblicazione']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tengo Un Plan', 'Key-Key', '2024-01-07']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Like That', 'Future, Metro Boomin, Kendrick Lamar', '2024-03-22']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['titolo', 'artista', 'pubblicazione']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Tengo Un Plan', 'Key-Key', '2024-01-07']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['Casca de Bala', 'Thullio Milionário', '2024-03-01']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Belong Together (Sped Up)', 'Lucky Socks', '2024-03-21']
# ['LAST NIGHT VERSÃO BH', 'DJ BIEL PRADO, Mc KF', '2024-04-12']
# ['Gata Only', 'FloyyMenor, Cris Mj', '2024-02-02']
# ['Woda Księżycowa', 'Kubi Producent, bambi, Fukaj, stickxr', '2024-03-22']
# ['Tell Ur Girlfriend', 'Lay Bankz', '2024-02-07']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Good Luck, Babe!', 'Chappell Roan', '2024-04-05']
# ['These Words', 'Badger, Natasha Bedingfield', '2024-04-05']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Karma', 'JoJo Siwa', '2024-04-05']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tu Kya Jaane (From "Amar Singh Chamkila")', 'Yashika Sikka, A.R. Rahman, Irshad Kamil', '2024-04-03']
# ['Tell Ur Girlfriend', 'Lay Bankz', '2024-02-07']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Good Luck, Babe!', 'Chappell Roan', '2024-04-05']
# ['These Words', 'Badger, Natasha Bedingfield', '2024-04-05']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Karma', 'JoJo Siwa', '2024-04-05']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tu Kya Jaane (From "Amar Singh Chamkila")', 'Yashika Sikka, A.R. Rahman, Irshad Kamil', '2024-04-03']
# ['Tell Ur Girlfriend', 'Lay Bankz', '2024-02-07']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Good Luck, Babe!', 'Chappell Roan', '2024-04-05']
# ['These Words', 'Badger, Natasha Bedingfield', '2024-04-05']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Karma', 'JoJo Siwa', '2024-04-05']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['Too Sweet', 'Hozier', '2024-03-22']
# ['Tu Kya Jaane (From "Amar Singh Chamkila")', 'Yashika Sikka, A.R. Rahman, Irshad Kamil', '2024-04-03']
# ['LET THE WORLD BURN', 'Chris Grey', '2024-03-08']
# ['titolo', 'artista', 'pubblicazione']
# ['Pedro', 'Jaxomy, Agatino Romero, Raffaella Carrà', '2024-03-29']
# ['Good Luck, Babe!', 'Chappell Roan', '2024-04-05']
# ['Anuvanuvuu', 'Sunny M.R., Arijit Singh, Krishna Kanth', '2024-03-26']
# ['These Words', 'Badger, Natasha Bedingfield', '2024-04-05']
# ['Mtg Forró e Desmantelo', 'dj sv, Doug Hits, Manim Vaqueiro', '2024-03-20']
# ['Ishq - From "Lost;Found"', 'Faheem Abdullah, Rauhan Malik', '2024-03-09']
# ['i like the way you kiss me', 'Artemas', '2024-03-19']
# ['Karma', 'JoJo Siwa', '2024-04-05']
# ['Magnetic', 'ILLIT', '2024-03-25']
# ['LET THE WORLD BURN', 'Chris Grey', '2024-03-08']
# titolo: 15
# Magnetic: 15
# i like the way you kiss me: 15
# Ishq - From "Lost;Found": 15
# Too Sweet: 14
# Belong Together (Sped Up): 10
# LAST NIGHT VERSÃO BH: 10
# Pedro: 10
# Casca de Bala: 8
# Gata Only: 8
# Woda Księżycowa: 7
# Tengo Un Plan: 5
# Like That: 4
# Good Luck, Babe!: 4
# These Words: 4
# Karma: 4
# Belong Together: 3
# Tell Ur Girlfriend: 3
# Tu Kya Jaane (From "Amar Singh Chamkila"): 3
# End of Beginning: 2
# LET THE WORLD BURN: 2
# Midnight Fiction: 1
# ¿Cómo Pasó?: 1
# Anuvanuvuu: 1
# Mtg Forró e Desmantelo: 1
