# %%
from traceback import print_tb
import networkx as nx
import csv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time

#----INIZIO----API-SPOTIFY----INIZIO----

#ID della mia applicazione su account spotify
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id="f01bf64d770a48b098b130b8cdc62b47",client_secret="546e3a93ca524544b122006002c9e6e9"))

#apro il file playlist che contiene il nome dell'utente e il link alla sua playlist
#metto i dati nella lista people
people = list()
with open('global.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        people.append(row)

del people[0]
#questo è il mio dataset a ogni indice corrisponde una lista di codici ISRC (30 per playlist tranne in rari casi)
dataset = list()

#prendo il link della playlist dalla lista people creata prima
#dal link estraggo l'id della playlist
#dall'id della playlist estraggo tutti i brani da ogni brano estraggo il codice ISRC
j = 0
aux = {}
pausa = 0
pausaPaese = 0

# %%
for s in range(5,6):
    pausaPaese += 1
    if pausaPaese % 8 == 0:
        time.sleep(35)
    print('prossimo paese')
    #prendo il link della playlist da person 
    playlist = spotify.playlist(people[s]["Link"])
    #dal link estraggo l'id della playlist
    songs = spotify.playlist_items(playlist["id"]) 
    #print(songs)
    for i in range (len(songs["items"])):
        pausa += 1
        if pausa % 8 == 0:
            time.sleep(35)
        print('dentro al ciclo')
        #print(j)
        isrc = songs["items"][i]["track"]["external_ids"]["isrc"]
        track_uri = songs["items"][i]["track"]["uri"]
        artist_uri = songs["items"][i]["track"]["artists"][0]["uri"]
        genres = spotify.artist(artist_uri)["genres"]

        danceability = 0
        try:
            danceability = spotify.audio_features(track_uri)[0]['danceability']
        except:
            pass

        energy = 0
        try:
            energy = spotify.audio_features(track_uri)[0]['energy']
        except:
            pass

        speechiness = 0
        try:
            speechiness = spotify.audio_features(track_uri)[0]['speechiness']
        except:
            pass

        acousticness = 0
        try:
            acousticness = spotify.audio_features(track_uri)[0]['acousticness']
        except:
            pass

        instrumentalness = 0
        try:
            instrumentalness = spotify.audio_features(track_uri)[0]['instrumentalness']
        except:
            pass

        valence = 0
        try:
            valence = spotify.audio_features(track_uri)[0]['valence']
        except:
            pass

        tempo = 0
        try:
            tempo = spotify.audio_features(track_uri)[0]['tempo']
        except:
            pass

        aux[j] = {"paese": people[s]["Name"],"isrc":isrc,"uri":track_uri,"genres":genres,"danceability":danceability,"energy":energy,"speechiness":speechiness,"acousticness":acousticness,"instrumentalness":instrumentalness,"valence":valence,"tempo":tempo}
        j = j+1
        #print(j)
pausaPaese = 0
print('uscito dal ciclo')
print(aux)
# Out:
# prossimo paese
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# dentro al ciclo
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# uscito dal ciclo
# {0: {'paese': 'Arabia_Saudita', 'isrc': 'GBKPL2205058', 'uri': 'spotify:track:3qhlB30KknSejmIvZZLjOD', 'genres': ['pov: indie', 'psychedelic pop'], 'danceability': 0.689, 'energy': 0.454, 'speechiness': 0.0584, 'acousticness': 0.0351, 'instrumentalness': 0.00259, 'valence': 0.912, 'tempo': 159.982}, 1: {'paese': 'Arabia_Saudita', 'isrc': 'USA2P2251865', 'uri': 'spotify:track:3Ua0m0YmEjrMi9XErKcNiR', 'genres': ['k-pop'], 'danceability': 0.629, 'energy': 0.733, 'speechiness': 0.0419, 'acousticness': 0.0025, 'instrumentalness': 0, 'valence': 0.362, 'tempo': 120.001}, 2: {'paese': 'Arabia_Saudita', 'isrc': 'QZJ842400387', 'uri': 'spotify:track:2GxrNKugF82CnoRFbQfzPf', 'genres': [], 'danceability': 0.599, 'energy': 0.946, 'speechiness': 0.0447, 'acousticness': 0.000938, 'instrumentalness': 0.0106, 'valence': 0.747, 'tempo': 151.647}, 3: {'paese': 'Arabia_Saudita', 'isrc': 'USUM72317276', 'uri': 'spotify:track:51ZQ1vr10ffzbwIjDCwqm4', 'genres': ['pop'], 'danceability': 0.645, 'energy': 0.663, 'speechiness': 0.0447, 'acousticness': 0.0657, 'instrumentalness': 3.18e-05, 'valence': 0.287, 'tempo': 115.83}, 4: {'paese': 'Arabia_Saudita', 'isrc': 'USSM12305010', 'uri': 'spotify:track:42VsgItocQwOQC3XWZ8JNA', 'genres': ['hip hop', 'rap', 'slap house'], 'danceability': 0.569, 'energy': 0.882, 'speechiness': 0.06, 'acousticness': 0.0316, 'instrumentalness': 0, 'valence': 0.201, 'tempo': 148.038}, 5: {'paese': 'Arabia_Saudita', 'isrc': 'USJ5G2335007', 'uri': 'spotify:track:3vkCueOmm7xQDoJ17W1Pm3', 'genres': ['brooklyn indie', 'pov: indie'], 'danceability': 0.504, 'energy': 0.308, 'speechiness': 0.0321, 'acousticness': 0.868, 'instrumentalness': 0.135, 'valence': 0.121, 'tempo': 113.95}, 6: {'paese': 'Arabia_Saudita', 'isrc': 'USUG12303881', 'uri': 'spotify:track:7CyPwkp0oE8Ro9Dd5CUDjW', 'genres': ['canadian contemporary r&b', 'canadian pop', 'pop'], 'danceability': 0.522, 'energy': 0.641, 'speechiness': 0.0318, 'acousticness': 0.0545, 'instrumentalness': 0, 'valence': 0.202, 'tempo': 87.51}, 7: {'paese': 'Arabia_Saudita', 'isrc': 'USA2P2402103', 'uri': 'spotify:track:3lwK3WyKAI5bUuGY1OgGbZ', 'genres': ['k-pop girl group'], 'danceability': 0.799, 'energy': 0.675, 'speechiness': 0.0465, 'acousticness': 0.115, 'instrumentalness': 0, 'valence': 0.594, 'tempo': 113.076}, 8: {'paese': 'Arabia_Saudita', 'isrc': 'USA2P2339030', 'uri': 'spotify:track:2N0SPREDYqILVEFSsWF5N5', 'genres': ['j-division', 'korean ost'], 'danceability': 0.633, 'energy': 0.607, 'speechiness': 0.0532, 'acousticness': 0.183, 'instrumentalness': 1.38e-06, 'valence': 0.363, 'tempo': 74.029}, 9: {'paese': 'Arabia_Saudita', 'isrc': 'USA2P2330093', 'uri': 'spotify:track:2HRgqmZQC0MC7GeNuDIXHN', 'genres': ['k-pop'], 'danceability': 0.79, 'energy': 0.831, 'speechiness': 0.044, 'acousticness': 0.312, 'instrumentalness': 0, 'valence': 0.872, 'tempo': 124.987}, 10: {'paese': 'Arabia_Saudita', 'isrc': 'USA2P2413259', 'uri': 'spotify:track:1aKvZDoLGkNMxoRYgkckZG', 'genres': [], 'danceability': 0.797, 'energy': 0.668, 'speechiness': 0.0687, 'acousticness': 0.257, 'instrumentalness': 0, 'valence': 0.69, 'tempo': 131.067}, 11: {'paese': 'Arabia_Saudita', 'isrc': 'USRC12301932', 'uri': 'spotify:track:3rUGC1vUpkDG9CZFHMur1t', 'genres': ['pop'], 'danceability': 0.75, 'energy': 0.733, 'speechiness': 0.0319, 'acousticness': 0.256, 'instrumentalness': 0, 'valence': 0.844, 'tempo': 111.018}, 12: {'paese': 'Arabia_Saudita', 'isrc': 'USRC12400507', 'uri': 'spotify:track:3QJsSWa0Xo8MfaRn1gr4Be', 'genres': ['dark r&b', 'hyperpop', 'sped up'], 'danceability': 0.726, 'energy': 0.652, 'speechiness': 0.0779, 'acousticness': 0.00323, 'instrumentalness': 0.003, 'valence': 0.625, 'tempo': 97.032}, 13: {'paese': 'Arabia_Saudita', 'isrc': 'QM4TX2453776', 'uri': 'spotify:track:67smGwuPEtA6GAfeweAVNO', 'genres': ['krushfunk'], 'danceability': 0.681, 'energy': 0.773, 'speechiness': 0.0345, 'acousticness': 0.0863, 'instrumentalness': 0.734, 'valence': 0.504, 'tempo': 129.923}, 14: {'paese': 'Arabia_Saudita', 'isrc' ...

# %%
print(aux.get(192))
# Out:
# {'paese': 'Austria', 'isrc': 'DEVY22400014', 'uri': 'spotify:track:7ciTcePUxWjBbaouXk7Bvf', 'genres': ['german drill', 'german hip hop'], 'danceability': 0.827, 'energy': 0.903, 'speechiness': 0.0538, 'acousticness': 0.359, 'instrumentalness': 0.0234, 'valence': 0.887, 'tempo': 114.975}

# %%
with open('machine-global01.csv', 'w+', newline='', encoding='utf-16') as file:
    writer = csv.DictWriter(file,fieldnames=["paese","isrc","uri","genres","danceability","energy","speechiness","acousticness","instrumentalness","valence","tempo"])
    #scrive Id Label nel file csv come intestazione
    writer.writeheader()
    #scrive id affiancato da nome nel file
    for i in range (j) :
        print('scrivo il file')
        #print(i)
        writer.writerow(aux[i])

#----FINE----API-SPOTIFY----FINE----'''
# Out:
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file
# scrivo il file

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.3-py3-none-any.whl.metadata (9.3 kB)
# Collecting requests>=2.25.0 (from spotipy)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six>=1.15.0 in c:\users\cola0\appdata\roaming\python\python312\site-packages (from spotipy) (1.16.0)
# Collecting urllib3>=1.26.0 (from spotipy)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25.0->spotipy)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.25.0->spotipy)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.25.0->spotipy)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Downloading redis-5.0.3-py3-none-any.whl (251 kB)
#    ---------------------------------------- 0.0/251.8 kB ? eta -:--:--
#    --------------------------------------- 251.8/251.8 kB 15.1 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB ? eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    --------------------------------------- 163.8/163.8 kB 10.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB ? eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB ? eta 0:00:00
# Installing collected packages: urllib3, redis, idna, charset-normalizer, certifi, requests, spotipy
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.7 redis-5.0.3 requests-2.31.0 spotipy-2.23.0 urllib3-2.2.1
# Note: you may need to restart the kernel to use updated packages.
